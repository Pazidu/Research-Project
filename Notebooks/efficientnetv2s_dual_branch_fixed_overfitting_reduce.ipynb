# %% [markdown]
# <a href="https://colab.research.google.com/github/Pazidu/Research-Project/blob/main/efficientnetv2s_dual_branch_fixed_overfitting_reduce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
import os
import shutil
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.applications import EfficientNetV2S
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import mixed_precision
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input

print("TensorFlow version:", tf.__version__)
print("GPU:", tf.test.gpu_device_name())
# Out:
# TensorFlow version: 2.20.0
# GPU: /device:GPU:0

# %%
BASE            = "/content/newdata"
IMG_SRC         = "/drive/MyDrive/Colab Notebooks/newdata"
CHECKPOINT_DIR  = "/drive/MyDrive/checkpoints"
MODEL_SAVE_PATH = "/drive/MyDrive/Colab Notebooks/Models/dermoscopy/efficientnetv2s_dual_branch.keras"

# %%
if os.path.exists(BASE):
    shutil.rmtree(BASE)
shutil.copytree(IMG_SRC, BASE)
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

# %%
mixed_precision.set_global_policy("float32")

BATCH_SIZE   = 16
IMAGE_SIZE   = 256
FUSION_LAYER = "block4c_add"
EPOCHS       = 25

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.15),
    layers.RandomZoom(0.1),
    layers.RandomBrightness(0.1),
    layers.RandomContrast(0.1),
], name="data_augmentation")

# %%
def add_edge_map(image, label):
    image = tf.cast(image, tf.float32)
    image = preprocess_input(image)
    gray  = tf.image.rgb_to_grayscale(image)
    sobel = tf.image.sobel_edges(gray)
    edge  = tf.sqrt(tf.reduce_sum(tf.square(sobel), axis=-1))
    edge  = edge / (tf.reduce_max(edge) + 1e-6)
    return (image, edge), label

# %%
def prepare_dataset(path, shuffle, training=False):
    ds = tf.keras.preprocessing.image_dataset_from_directory(
        path,
        image_size=(IMAGE_SIZE, IMAGE_SIZE),
        batch_size=BATCH_SIZE,
        label_mode="categorical",
        shuffle=shuffle,
    )
    if training:
        ds = ds.map(
            lambda x, y: (data_augmentation(x, training=True), y),
            num_parallel_calls=tf.data.AUTOTUNE,
        )
    ds = ds.map(add_edge_map, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds


train_ds = prepare_dataset(f"{BASE}/train", shuffle=True,  training=True)
val_ds   = prepare_dataset(f"{BASE}/valid", shuffle=False, training=False)
test_ds  = prepare_dataset(f"{BASE}/test",  shuffle=False, training=False)
# Out:
# Found 8012 files belonging to 2 classes.
# Found 1001 files belonging to 2 classes.
# Found 1002 files belonging to 2 classes.

# %%
def create_dual_model(num_train_batches):
    # --- RGB branch ---
    rgb_input  = layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3), name="rgb_input")
    base_model = EfficientNetV2S(
        include_top=False,
        weights="imagenet",
        input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3),
    )

    # Freeze all but last 40 layers (middle ground: more expressive than 30,
    # more regularised than 50)
    for layer in base_model.layers[:-40]:
        layer.trainable = False

    feature_extractor = tf.keras.Model(
        inputs=base_model.input,
        outputs=base_model.get_layer(FUSION_LAYER).output,
    )
    middle_feature = feature_extractor(rgb_input)

    # --- Edge branch ---
    edge_input = layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 1), name="edge_input")
    x = layers.Conv2D(32,  3, activation="relu", padding="same")(edge_input)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Conv2D(64,  3, activation="relu", padding="same")(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Conv2D(128, 3, activation="relu", padding="same")(x)
    x = layers.Resizing(middle_feature.shape[1], middle_feature.shape[2])(x)
    x = layers.Conv2D(middle_feature.shape[-1], 1, padding="same")(x)

    # --- Feature fusion ---
    fused = layers.Concatenate()([middle_feature, x])
    fused = layers.Conv2D(256, 3, activation="relu", padding="same")(fused)
    fused = layers.BatchNormalization()(fused)
    fused = layers.GlobalAveragePooling2D()(fused)
    fused = layers.Dense(
        256, activation="relu",
        kernel_regularizer=tf.keras.regularizers.l2(1e-4),
    )(fused)
    fused = layers.Dropout(0.6)(fused)
    outputs = layers.Dense(2, activation="softmax")(fused)

    # --- Cosine annealing LR (replaces ReduceLROnPlateau) ---
    cosine_lr = tf.keras.optimizers.schedules.CosineDecay(
        initial_learning_rate=1e-4,
        decay_steps=EPOCHS * num_train_batches,
    )

    model = tf.keras.Model(inputs=[rgb_input, edge_input], outputs=outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(cosine_lr),
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
        metrics=["accuracy"],
    )
    return model

# %%
model = create_dual_model(num_train_batches=len(train_ds))
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-s_notop.h5
# 82420632/82420632 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ edge_input          │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        320 │ edge_input[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │     73,856 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rgb_input           │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ resizing (Resizing) │ (None, 16, 16,    │          0 │ conv2d_2[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_1        │ (None, 16, 16,    │  1,317,880 │ rgb_input[0][0]   │
# │ (Functional)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 16, 16,    │     16,512 │ resizing[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ functional_1[0][… │
# │ (Concatenate)       │ 256)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 16, 16,    │    590,080 │ concatenate[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 16, 16,    │      1,024 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │     65,792 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 2)         │        514 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,084,474 (7.95 MB)
#  Trainable params: 766,082 (2.92 MB)
#  Non-trainable params: 1,318,392 (5.03 MB)

# %%
checkpoint_best = ModelCheckpoint(
    filepath=f"{CHECKPOINT_DIR}/best_dual_{FUSION_LAYER}.keras",
    monitor="val_accuracy",
    save_best_only=True,
    verbose=1,
)

early_stopping = EarlyStopping(
    monitor="val_accuracy",
    patience=7,
    restore_best_weights=True,
    verbose=1,
)

# %%
history = model.fit(
    train_ds,
    epochs=EPOCHS,
    validation_data=val_ds,
    callbacks=[checkpoint_best, early_stopping],
)
# Out:
# Epoch 1/25
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.8351 - loss: 0.4890
# Epoch 1: val_accuracy improved from None to 0.78521, saving model to /drive/MyDrive/checkpoints/best_dual_block4c_add.keras
#
# Epoch 1: finished saving model to /drive/MyDrive/checkpoints/best_dual_block4c_add.keras
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 301s 545ms/step - accuracy: 0.8751 - loss: 0.4439 - val_accuracy: 0.7852 - val_loss: 0.4898
# Epoch 2/25
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.8915 - loss: 0.4146
# Epoch 2: val_accuracy improved from 0.78521 to 0.84615, saving model to /drive/MyDrive/checkpoints/best_dual_block4c_add.keras
#
# Epoch 2: finished saving model to /drive/MyDrive/checkpoints/best_dual_block4c_add.keras
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 248s 494ms/step - accuracy: 0.8942 - loss: 0.4072 - val_accuracy: 0.8462 - val_loss: 0.4462
# Epoch 3/25
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - accuracy: 0.9017 - loss: 0.3948
# Epoch 3: val_accuracy did not improve from 0.84615
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 248s 495ms/step - accuracy: 0.9015 - loss: 0.3919 - val_accuracy: 0.8212 - val_loss: 0.4672
# Epoch 4/25
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.9042 - loss: 0.3873
# Epoch 4: val_accuracy improved from 0.84615 to 0.86014, saving model to /drive/MyDrive/checkpoints/best_dual_block4c_add.keras
#
# Epoch 4: finished saving model to /drive/MyDrive/checkpoints/best_dual_block4c_add.keras
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 256s 482ms/step - accuracy: 0.9054 - loss: 0.3838 - val_accuracy: 0.8601 - val_loss: 0.4343
# Epoch 5/25
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.9069 - loss: 0.3836
# Epoch 5: val_accuracy did not improve from 0.86014
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 244s 486ms/step - accuracy: 0.9080 - loss: 0.3817 - val_accuracy: 0.8482 - val_loss: 0.4353
# Epoch 6/25
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9027 - loss: 0.3808
# Epoch 6: val_accuracy did not improve from 0.86014
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 258s 479ms/step - accuracy: 0.9053 - loss: 0.3776 - val_accuracy: 0.8152 - val_loss: 0.4797
# Epoch 7/25
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.9041 - loss: 0.3770
# Epoch 7: val_accuracy did not improve from 0.86014
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 250s 498ms/step - accuracy: 0.9085 - loss: 0.3742 - val_accuracy: 0.8472 - val_loss: 0.4549
# Epoch 8/25
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.9073 - loss: 0.3725
# Epoch 8: val_accuracy improved from 0.86014 to 0.88312, saving model to /drive/MyDrive/checkpoints/best_dual_block4c_add.keras
#
# Epoch 8: finished saving model to /drive/MyDrive/checkpoints/best_dual_block4c_add.keras
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 250s 498ms/step - accuracy: 0.9108 - loss: 0.3687 - val_accuracy: 0.8831 - val_loss: 0.4053
# Epoch 9/25
# 500/501 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9103 - loss: 0.3670
# Epoch 9: val_accuracy improved from 0.88312 to 0.88511, saving model to /drive/MyDrive/checkpoints/best_dual_block4c_add.keras
#
# Epoch 9: finished saving model to /drive/MyDrive/checkpoints/best_dual_block4c_add.keras
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 240s 478ms/step - accuracy: 0.9124 - loss: 0.3652 - val_accuracy: 0.8851 - val_loss: 0.4118
# Epoch 10/25
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.9173 - loss: 0.3616
# Epoch 10: val_accuracy did not improve from 0.88511
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 242s 481ms/step - accuracy: 0.9176 - loss: 0.3596 - val_accuracy: 0.8681 - val_loss: 0.4217
# Epoch 11/25
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.9146 - loss: 0.3657
# Epoch 11: val_accuracy did not improve from 0.88511
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 259s 475ms/step - accuracy: 0.9171 - loss: 0.3609 - val_accuracy: 0.8472 - val_loss: 0.4561
# Epoch 12/25
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.9167 - loss: 0.3544
# Epoch 12: val_accuracy did not improve from 0.88511
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 237s 473ms/step - accuracy: 0.9166 - loss: 0.3551 - val_accuracy: 0.8721 - val_loss: 0.4174
# Epoch 13/25
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.9147 - loss: 0.3533
# Epoch 13: val_accuracy did not improve from 0.88511
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 237s 472ms/step - accuracy: 0.9167 - loss: 0.3537 - val_accuracy: 0.8541 - val_loss: 0.4355
# Epoch 14/25
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step - accuracy: 0.9189 - loss: 0.3511
# Epoch 14: val_accuracy did not improve from 0.88511
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 238s 473ms/step - accuracy: 0.9201 - loss: 0.3502 - val_accuracy: 0.8511 - val_loss: 0.4478
# Epoch 15/25
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - accuracy: 0.9149 - loss: 0.3537
# Epoch 15: val_accuracy did not improve from 0.88511
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 238s 474ms/step - accuracy: 0.9182 - loss: 0.3508 - val_accuracy: 0.8721 - val_loss: 0.4193
# Epoch 16/25
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - accuracy: 0.9194 - loss: 0.3498
# Epoch 16: val_accuracy did not improve from 0.88511
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 238s 474ms/step - accuracy: 0.9211 - loss: 0.3476 - val_accuracy: 0.8711 - val_loss: 0.4212
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 9.

# %%
loss, acc = model.evaluate(test_ds)
print("Fusion layer :", FUSION_LAYER)
print(f"Test accuracy: {acc:.4f}")

model.save(MODEL_SAVE_PATH)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 20s 316ms/step - accuracy: 0.8733 - loss: 0.4228
# Fusion layer : block4c_add
# Test accuracy: 0.8733
