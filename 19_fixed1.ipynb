# %% [markdown]
# <a href="https://colab.research.google.com/github/Pazidu/Research-Project/blob/main/19_fixed1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
import os
import shutil
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.applications import EfficientNetV2S
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import mixed_precision
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input

tf.random.set_seed(42)
np.random.seed(42)

print("TensorFlow version:", tf.__version__)
print("GPU:", tf.test.gpu_device_name())
# Out:
# TensorFlow version: 2.20.0
# GPU: /device:GPU:0

# %%
BASE            = "/content/newdata"
IMG_SRC         = "/drive/MyDrive/Colab Notebooks/newdata"
CHECKPOINT_DIR  = "/drive/MyDrive/checkpoints"
MODEL_SAVE_PATH = "/drive/MyDrive/Colab Notebooks/Models/dermoscopy/efficientnetv2s_dual_branch_run10.keras"

# %%
if os.path.exists(BASE):
    shutil.rmtree(BASE)
shutil.copytree(IMG_SRC, BASE)
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

# %%
mixed_precision.set_global_policy("float32")

BATCH_SIZE       = 16
IMAGE_SIZE       = 256
FUSION_LAYER     = "block4c_add"
EPOCHS           = 30

N_TRAIN_TOTAL    = 7122 + 890
STEPS_PER_EPOCH  = N_TRAIN_TOTAL // BATCH_SIZE

CLASS_ORDER      = ["melanoma", "non_melanoma"]   # index 0 = melanoma, index 1 = non_melanoma

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.10),
    layers.RandomZoom(0.1),
], name="data_augmentation")

# %%
def add_edge_map(image, label):
    image = tf.cast(image, tf.float32)
    image = preprocess_input(image)
    gray  = tf.image.rgb_to_grayscale(image)
    sobel = tf.image.sobel_edges(gray)
    edge  = tf.sqrt(tf.reduce_sum(tf.square(sobel), axis=-1))
    edge  = edge / (tf.reduce_max(edge) + 1e-6)
    return (image, edge), label

# %%
def make_class_stream(base_path, only_class):
    """Infinite stream containing only `only_class` images, correctly labelled."""
    ds = tf.keras.preprocessing.image_dataset_from_directory(
        base_path,
        image_size=(IMAGE_SIZE, IMAGE_SIZE),
        batch_size=BATCH_SIZE // 2,
        label_mode="categorical",
        shuffle=True,
        class_names=CLASS_ORDER,
    )
    ds = ds.filter(lambda x, y: tf.equal(tf.argmax(y[0]), only_class))
    ds = ds.repeat()
    ds = ds.map(
        lambda x, y: (data_augmentation(x, training=True), y),
        num_parallel_calls=tf.data.AUTOTUNE,
    )
    return ds


melanoma_stream     = make_class_stream(f"{BASE}/train", only_class=0)
non_melanoma_stream = make_class_stream(f"{BASE}/train", only_class=1)

balanced_ds = tf.data.Dataset.sample_from_datasets(
    [melanoma_stream, non_melanoma_stream],
    weights=[0.5, 0.5],
)
balanced_ds = balanced_ds.map(add_edge_map, num_parallel_calls=tf.data.AUTOTUNE)
balanced_ds = balanced_ds.prefetch(tf.data.AUTOTUNE)
# Out:
# Found 8012 files belonging to 2 classes.
# Found 8012 files belonging to 2 classes.

# %%
def prepare_eval_dataset(path):
    ds = tf.keras.preprocessing.image_dataset_from_directory(
        path,
        image_size=(IMAGE_SIZE, IMAGE_SIZE),
        batch_size=BATCH_SIZE,
        label_mode="categorical",
        shuffle=False,
        class_names=CLASS_ORDER,
    )
    ds = ds.map(add_edge_map, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds


val_ds  = prepare_eval_dataset(f"{BASE}/valid")
test_ds = prepare_eval_dataset(f"{BASE}/test")
# Out:
# Found 1001 files belonging to 2 classes.
# Found 1002 files belonging to 2 classes.

# %%
def create_dual_model(steps_per_epoch):
    # --- RGB branch ---
    rgb_input  = layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3), name="rgb_input")
    base_model = EfficientNetV2S(
        include_top=False,
        weights="imagenet",
        input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3),
    )

    # <-- CHANGED: unfreeze last 60 layers instead of 40 (more backbone adaptation
    # for this fine-grained, visually-similar-classes task)
    for layer in base_model.layers[:-60]:
        layer.trainable = False

    feature_extractor = tf.keras.Model(
        inputs=base_model.input,
        outputs=base_model.get_layer(FUSION_LAYER).output,
    )
    middle_feature = feature_extractor(rgb_input)

    # --- Edge branch ---
    edge_input = layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 1), name="edge_input")
    x = layers.Conv2D(32,  3, activation="relu", padding="same")(edge_input)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Conv2D(64,  3, activation="relu", padding="same")(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Conv2D(128, 3, activation="relu", padding="same")(x)
    x = layers.Resizing(middle_feature.shape[1], middle_feature.shape[2])(x)
    x = layers.Conv2D(middle_feature.shape[-1], 1, padding="same")(x)

    # --- Feature fusion ---
    fused = layers.Concatenate()([middle_feature, x])
    fused = layers.Conv2D(256, 3, activation="relu", padding="same")(fused)
    fused = layers.BatchNormalization()(fused)
    fused = layers.GlobalAveragePooling2D()(fused)
    fused = layers.Dense(
        256, activation="relu",
        kernel_regularizer=tf.keras.regularizers.l2(1e-4),
    )(fused)
    fused   = layers.Dropout(0.5)(fused)
    outputs = layers.Dense(2, activation="softmax")(fused)

    cosine_lr = tf.keras.optimizers.schedules.CosineDecay(
        initial_learning_rate=2e-4,
        decay_steps=EPOCHS * steps_per_epoch,
    )

    model = tf.keras.Model(inputs=[rgb_input, edge_input], outputs=outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(cosine_lr),
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
        metrics=[
            "accuracy",
            tf.keras.metrics.AUC(name="auc"),
            tf.keras.metrics.Recall(name="sensitivity"),
            tf.keras.metrics.Recall(name="specificity", class_id=1),
            tf.keras.metrics.Precision(name="precision"),
        ],
    )
    return model

# %%
model = create_dual_model(steps_per_epoch=STEPS_PER_EPOCH)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-s_notop.h5
# 82420632/82420632 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ edge_input          │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        320 │ edge_input[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │     73,856 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rgb_input           │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ resizing (Resizing) │ (None, 16, 16,    │          0 │ conv2d_2[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_1        │ (None, 16, 16,    │  1,317,880 │ rgb_input[0][0]   │
# │ (Functional)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 16, 16,    │     16,512 │ resizing[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ functional_1[0][… │
# │ (Concatenate)       │ 256)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 16, 16,    │    590,080 │ concatenate[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 16, 16,    │      1,024 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │     65,792 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 2)         │        514 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,084,474 (7.95 MB)
#  Trainable params: 766,082 (2.92 MB)
#  Non-trainable params: 1,318,392 (5.03 MB)

# %%
checkpoint_best = ModelCheckpoint(
    filepath=f"{CHECKPOINT_DIR}/best_dual_{FUSION_LAYER}_run10.keras",  # <-- CHANGED: unique filename
    monitor="val_auc",
    save_best_only=True,
    verbose=1,
)

early_stopping = EarlyStopping(
    monitor="val_auc",
    patience=10,
    restore_best_weights=True,
    verbose=1,
)

# %%
history = model.fit(
    balanced_ds,
    epochs=EPOCHS,
    steps_per_epoch=STEPS_PER_EPOCH,
    validation_data=val_ds,
    callbacks=[checkpoint_best, early_stopping],
)
# Out:
# Epoch 1/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.7939 - auc: 0.8720 - loss: 0.4916 - precision: 0.7939 - sensitivity: 0.7939 - specificity: 0.8927
# Epoch 1: val_auc improved from None to 0.72644, saving model to /drive/MyDrive/checkpoints/best_dual_block4c_add_run10.keras
#
# Epoch 1: finished saving model to /drive/MyDrive/checkpoints/best_dual_block4c_add_run10.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 253s 455ms/step - accuracy: 0.8423 - auc: 0.9180 - loss: 0.4368 - precision: 0.8423 - sensitivity: 0.8423 - specificity: 0.9408 - val_accuracy: 0.6294 - val_auc: 0.7264 - val_loss: 0.7950 - val_precision: 0.6294 - val_sensitivity: 0.6294 - val_specificity: 0.5910
# Epoch 2/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.8471 - auc: 0.9267 - loss: 0.4201 - precision: 0.8471 - sensitivity: 0.8471 - specificity: 0.9391
# Epoch 2: val_auc improved from 0.72644 to 0.85325, saving model to /drive/MyDrive/checkpoints/best_dual_block4c_add_run10.keras
#
# Epoch 2: finished saving model to /drive/MyDrive/checkpoints/best_dual_block4c_add_run10.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 193s 386ms/step - accuracy: 0.8535 - auc: 0.9295 - loss: 0.4142 - precision: 0.8535 - sensitivity: 0.8535 - specificity: 0.9491 - val_accuracy: 0.7443 - val_auc: 0.8532 - val_loss: 0.5414 - val_precision: 0.7443 - val_sensitivity: 0.7443 - val_specificity: 0.7337
# Epoch 3/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.8719 - auc: 0.9459 - loss: 0.3786 - precision: 0.8719 - sensitivity: 0.8719 - specificity: 0.9547
# Epoch 3: val_auc improved from 0.85325 to 0.91219, saving model to /drive/MyDrive/checkpoints/best_dual_block4c_add_run10.keras
#
# Epoch 3: finished saving model to /drive/MyDrive/checkpoints/best_dual_block4c_add_run10.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 202s 405ms/step - accuracy: 0.8704 - auc: 0.9429 - loss: 0.3847 - precision: 0.8704 - sensitivity: 0.8704 - specificity: 0.9562 - val_accuracy: 0.8302 - val_auc: 0.9122 - val_loss: 0.4400 - val_precision: 0.8302 - val_sensitivity: 0.8302 - val_specificity: 0.8371
# Epoch 4/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.8643 - auc: 0.9369 - loss: 0.3963 - precision: 0.8643 - sensitivity: 0.8643 - specificity: 0.9584
# Epoch 4: val_auc improved from 0.91219 to 0.92139, saving model to /drive/MyDrive/checkpoints/best_dual_block4c_add_run10.keras
#
# Epoch 4: finished saving model to /drive/MyDrive/checkpoints/best_dual_block4c_add_run10.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 191s 383ms/step - accuracy: 0.8691 - auc: 0.9444 - loss: 0.3808 - precision: 0.8691 - sensitivity: 0.8691 - specificity: 0.9595 - val_accuracy: 0.8442 - val_auc: 0.9214 - val_loss: 0.4275 - val_precision: 0.8442 - val_sensitivity: 0.8442 - val_specificity: 0.8584
# Epoch 5/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.8783 - auc: 0.9530 - loss: 0.3607 - precision: 0.8783 - sensitivity: 0.8783 - specificity: 0.9564
# Epoch 5: val_auc improved from 0.92139 to 0.93236, saving model to /drive/MyDrive/checkpoints/best_dual_block4c_add_run10.keras
#
# Epoch 5: finished saving model to /drive/MyDrive/checkpoints/best_dual_block4c_add_run10.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 196s 393ms/step - accuracy: 0.8777 - auc: 0.9510 - loss: 0.3652 - precision: 0.8777 - sensitivity: 0.8777 - specificity: 0.9574 - val_accuracy: 0.8561 - val_auc: 0.9324 - val_loss: 0.4054 - val_precision: 0.8561 - val_sensitivity: 0.8561 - val_specificity: 0.8685
# Epoch 6/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.8940 - auc: 0.9567 - loss: 0.3503 - precision: 0.8940 - sensitivity: 0.8940 - specificity: 0.9696
# Epoch 6: val_auc did not improve from 0.93236
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 202s 405ms/step - accuracy: 0.8879 - auc: 0.9566 - loss: 0.3514 - precision: 0.8879 - sensitivity: 0.8879 - specificity: 0.9653 - val_accuracy: 0.8551 - val_auc: 0.9276 - val_loss: 0.4159 - val_precision: 0.8551 - val_sensitivity: 0.8551 - val_specificity: 0.8685
# Epoch 7/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.8808 - auc: 0.9512 - loss: 0.3645 - precision: 0.8808 - sensitivity: 0.8808 - specificity: 0.9611
# Epoch 7: val_auc did not improve from 0.93236
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 198s 397ms/step - accuracy: 0.8842 - auc: 0.9533 - loss: 0.3593 - precision: 0.8842 - sensitivity: 0.8842 - specificity: 0.9663 - val_accuracy: 0.8432 - val_auc: 0.9196 - val_loss: 0.4337 - val_precision: 0.8432 - val_sensitivity: 0.8432 - val_specificity: 0.8483
# Epoch 8/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.8767 - auc: 0.9523 - loss: 0.3616 - precision: 0.8767 - sensitivity: 0.8767 - specificity: 0.9598
# Epoch 8: val_auc did not improve from 0.93236
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 186s 373ms/step - accuracy: 0.8924 - auc: 0.9597 - loss: 0.3428 - precision: 0.8924 - sensitivity: 0.8924 - specificity: 0.9667 - val_accuracy: 0.7752 - val_auc: 0.8596 - val_loss: 0.5666 - val_precision: 0.7752 - val_sensitivity: 0.7752 - val_specificity: 0.7652
# Epoch 9/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.8986 - auc: 0.9627 - loss: 0.3336 - precision: 0.8986 - sensitivity: 0.8986 - specificity: 0.9709
# Epoch 9: val_auc did not improve from 0.93236
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 197s 394ms/step - accuracy: 0.8910 - auc: 0.9605 - loss: 0.3400 - precision: 0.8910 - sensitivity: 0.8910 - specificity: 0.9686 - val_accuracy: 0.7752 - val_auc: 0.8644 - val_loss: 0.5530 - val_precision: 0.7752 - val_sensitivity: 0.7752 - val_specificity: 0.7652
# Epoch 10/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.8882 - auc: 0.9616 - loss: 0.3381 - precision: 0.8882 - sensitivity: 0.8882 - specificity: 0.9631
# Epoch 10: val_auc did not improve from 0.93236
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 195s 391ms/step - accuracy: 0.8875 - auc: 0.9616 - loss: 0.3371 - precision: 0.8875 - sensitivity: 0.8875 - specificity: 0.9654 - val_accuracy: 0.7922 - val_auc: 0.8644 - val_loss: 0.5403 - val_precision: 0.7922 - val_sensitivity: 0.7922 - val_specificity: 0.7809
# Epoch 11/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.8838 - auc: 0.9575 - loss: 0.3470 - precision: 0.8838 - sensitivity: 0.8838 - specificity: 0.9655
# Epoch 11: val_auc did not improve from 0.93236
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 194s 390ms/step - accuracy: 0.8831 - auc: 0.9585 - loss: 0.3447 - precision: 0.8831 - sensitivity: 0.8831 - specificity: 0.9597 - val_accuracy: 0.7792 - val_auc: 0.8600 - val_loss: 0.5550 - val_precision: 0.7792 - val_sensitivity: 0.7792 - val_specificity: 0.7719
# Epoch 12/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.9081 - auc: 0.9666 - loss: 0.3214 - precision: 0.9081 - sensitivity: 0.9081 - specificity: 0.9737
# Epoch 12: val_auc did not improve from 0.93236
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 191s 382ms/step - accuracy: 0.9075 - auc: 0.9684 - loss: 0.3167 - precision: 0.9075 - sensitivity: 0.9075 - specificity: 0.9709 - val_accuracy: 0.8412 - val_auc: 0.9224 - val_loss: 0.4285 - val_precision: 0.8412 - val_sensitivity: 0.8412 - val_specificity: 0.8528
# Epoch 13/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.8983 - auc: 0.9670 - loss: 0.3218 - precision: 0.8983 - sensitivity: 0.8983 - specificity: 0.9672
# Epoch 13: val_auc did not improve from 0.93236
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 199s 398ms/step - accuracy: 0.9000 - auc: 0.9676 - loss: 0.3209 - precision: 0.9000 - sensitivity: 0.9000 - specificity: 0.9672 - val_accuracy: 0.8172 - val_auc: 0.8942 - val_loss: 0.4818 - val_precision: 0.8172 - val_sensitivity: 0.8172 - val_specificity: 0.8146
# Epoch 14/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.8989 - auc: 0.9662 - loss: 0.3236 - precision: 0.8989 - sensitivity: 0.8989 - specificity: 0.9716
# Epoch 14: val_auc did not improve from 0.93236
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 193s 386ms/step - accuracy: 0.8935 - auc: 0.9645 - loss: 0.3289 - precision: 0.8935 - sensitivity: 0.8935 - specificity: 0.9670 - val_accuracy: 0.7992 - val_auc: 0.8628 - val_loss: 0.5489 - val_precision: 0.7992 - val_sensitivity: 0.7992 - val_specificity: 0.7854
# Epoch 15/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.8996 - auc: 0.9667 - loss: 0.3222 - precision: 0.8996 - sensitivity: 0.8996 - specificity: 0.9684
# Epoch 15: val_auc did not improve from 0.93236
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 184s 368ms/step - accuracy: 0.8954 - auc: 0.9673 - loss: 0.3209 - precision: 0.8954 - sensitivity: 0.8954 - specificity: 0.9668 - val_accuracy: 0.8092 - val_auc: 0.8769 - val_loss: 0.5257 - val_precision: 0.8092 - val_sensitivity: 0.8092 - val_specificity: 0.7978
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.

# %%
print("\n── Test results (run 10: 60 unfrozen layers) ──")
results = model.evaluate(test_ds)
for name, val in zip(model.metrics_names, results):
    print(f"  {name}: {val:.4f}")

model.save(MODEL_SAVE_PATH)
# Out:
# ── Test results (run 10: 60 unfrozen layers) ──
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 21s 338ms/step - accuracy: 0.8513 - auc: 0.9281 - loss: 0.4111 - precision: 0.8513 - sensitivity: 0.8513 - specificity: 0.8663
#   loss: 0.4111
#   compile_metrics: 0.8513
